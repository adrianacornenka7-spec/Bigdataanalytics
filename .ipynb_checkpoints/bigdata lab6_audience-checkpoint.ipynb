# %%
import geopandas as gpd
from pathlib import Path

# Define path do the data
data_folder = Path("data/_data/Austin")
fp = data_folder / "austin_pop_density_2019.gpkg"

# Read in the data and check the contents
data = gpd.read_file(fp)
data.head()
# Out:
#    pop2019   tract  area_km2  pop_density_km2  \
# 0   6070.0  002422  4.029772      1506.288778
# 1   2203.0  001751  1.532030      1437.961394
# 2   7419.0  002411  3.960344      1873.322161
# 3   4229.0  000401  2.181762      1938.341859
# 4   4589.0  002313  2.431208      1887.538658
#
#                                             geometry
# 0  MULTIPOLYGON (((615643.488 3338728.496, 615645...
# 1  MULTIPOLYGON (((618576.586 3359381.053, 618614...
# 2  MULTIPOLYGON (((619200.163 3341784.654, 619270...
# 3  MULTIPOLYGON (((621623.757 3350508.165, 621656...
# 4  MULTIPOLYGON (((621630.247 3345130.744, 621717...

# %%
data["geometry"].head()
# Out:
# 0    MULTIPOLYGON (((615643.488 3338728.496, 615645...
# 1    MULTIPOLYGON (((618576.586 3359381.053, 618614...
# 2    MULTIPOLYGON (((619200.163 3341784.654, 619270...
# 3    MULTIPOLYGON (((621623.757 3350508.165, 621656...
# 4    MULTIPOLYGON (((621630.247 3345130.744, 621717...
# Name: geometry, dtype: geometry

# %%
# Check data type of the geometry column
type(data["geometry"])
# Out:
# geopandas.geoseries.GeoSeries

# %%
# Check data type of a value in the geometry column
type(data["geometry"].values[0])
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
import matplotlib.pyplot as plt

data.plot(facecolor="none", linewidth=0.2)

plt.axis("off")
plt.show()

# %%
data.crs.name
# Out:
# 'WGS 84 / UTM zone 14N'

# %%
data["geometry"].centroid.head()
# Out:
# 0     POINT (616990.19 3339736.002)
# 1    POINT (619378.303 3359650.002)
# 2    POINT (620418.753 3342194.171)
# 3    POINT (622613.506 3351414.386)
# 4    POINT (622605.359 3343869.554)
# dtype: geometry

# %%
data.centroid.plot(markersize=1)

plt.axis("off")
plt.show()

# %%
data.union_all()
# Out:
# <MULTIPOLYGON (((618127.375 3340167.455, 618106.392 3340130.428, 617961.619 ...>

# %%
# Merge geometries using coverage algorithm
dissolved = data.dissolve(method="coverage")
dissolved.head()
# Out:
#                                             geometry  pop2019   tract  \
# 0  MULTIPOLYGON (((618353.957 3340531.11, 618350....   6070.0  002422
#
#    area_km2  pop_density_km2
# 0  4.029772      1506.288778

# %%
# Get the shapely geometry
dissolved.geometry[0]
# Out:
# <MULTIPOLYGON (((618353.957 3340531.11, 618350.074 3340525.423, 618247.419 3...>

# %%
data.envelope.head()
# Out:
# 0    POLYGON ((615643.488 3337909.895, 618358.033 3...
# 1    POLYGON ((618529.497 3358797, 620192.632 33587...
# 2    POLYGON ((619198.456 3340875.421, 621733.88 33...
# 3    POLYGON ((621599.087 3350329.32, 623714.365 33...
# 4    POLYGON ((621630.247 3343015.679, 624133.189 3...
# dtype: geometry

# %%
data.union_all().envelope
# Out:
# <POLYGON ((608125.394 3337909.895, 629828.389 3337909.895, 629828.389 337051...>

# %%
data.total_bounds
# Out:
# array([ 608125.39429998, 3337909.89499998,  629828.38850021,
#        3370513.68260002])

# %%
data.bounds.head()
# Out:
#           minx          miny         maxx          maxy
# 0  615643.4875  3.337910e+06  618358.0327  3.341257e+06
# 1  618529.4971  3.358797e+06  620192.6319  3.360614e+06
# 2  619198.4560  3.340875e+06  621733.8796  3.343443e+06
# 3  621599.0866  3.350329e+06  623714.3655  3.352436e+06
# 4  621630.2470  3.343016e+06  624133.1887  3.345131e+06

# %%
data.dissolve().minimum_rotated_rectangle().geometry[0]
# Out:
# <POLYGON ((607406.689 3339728.62, 614479.551 3370805.997, 631921.478 3366836...>

# %%
data.dissolve().minimum_bounding_circle().geometry[0]
# Out:
# <POLYGON ((632628.702 3354211.789, 632315.286 3351029.615, 631387.08 3347969...>

# %%
data.convex_hull.head()
# Out:
# 0    POLYGON ((616870.883 3337909.895, 616852.964 3...
# 1    POLYGON ((619496.705 3358797, 618962.703 33590...
# 2    POLYGON ((619848.5 3340875.421, 619811.394 334...
# 3    POLYGON ((622145.426 3350329.32, 622132.429 33...
# 4    POLYGON ((623931.77 3343015.679, 622426.307 33...
# dtype: geometry

# %%
data.union_all().convex_hull
# Out:
# <POLYGON ((616870.883 3337909.895, 616852.964 3337910.04, 616658.188 3337913...>

# %%
data.concave_hull().head()
# Out:
# 0    POLYGON ((616686.447 3341251.083, 616689.559 3...
# 1    POLYGON ((619414.904 3360602.695, 619418.528 3...
# 2    POLYGON ((620165.029 3343417.634, 620177.845 3...
# 3    POLYGON ((622361.001 3352408.88, 622364.565 33...
# 4    POLYGON ((621654.405 3344983.596, 621630.247 3...
# dtype: geometry

# %%
concave_hull = data.dissolve().concave_hull()
concave_hull.plot();

# %%
# Create GeoDataFrame of the union
gdf_union = data.dissolve()

# Ratio 0.05
concave_hull_a = gdf_union.concave_hull(ratio=0.05)

# Ratio 0.2
concave_hull_b = gdf_union.concave_hull(ratio=0.2)

# Ratio 0.4
concave_hull_c = gdf_union.concave_hull(ratio=0.4)

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)

# Plot side by side
concave_hull_a.plot(ax=ax1)
concave_hull_b.plot(ax=ax2)
concave_hull_c.plot(ax=ax3)

# Remove axis texts
ax1.axis("off")
ax2.axis("off")
ax3.axis("off")

# Add titles
ax1.set_title("Ratio 0.05")
ax2.set_title("Ratio 0.2")
ax3.set_title("Ratio 0.4");

# %%
data.simplify(tolerance=1000).head()
# Out:
# 0    POLYGON ((615643.488 3338728.496, 616689.559 3...
# 1    POLYGON ((619496.705 3358797, 619418.528 33606...
# 2    POLYGON ((619200.163 3341784.654, 620177.845 3...
# 3    POLYGON ((621623.757 3350508.165, 622387.916 3...
# 4    POLYGON ((621630.247 3345130.744, 624133.189 3...
# dtype: geometry

# %%
data.union_all().simplify(tolerance=1000)
# Out:
# <MULTIPOLYGON (((618127.375 3340167.455, 616870.883 3337909.895, 612472.864 ...>

# %%
# 1000 m buffer for each polygon
data.buffer(1000).plot(edgecolor="white")

plt.axis("off")
plt.show()

# %%
# 1000 m buffer for each polygon
data.union_all().buffer(1000)
# Out:
# <POLYGON ((607231.975 3343405.344, 607257.443 3343479.568, 607303.623 334357...>

# %%
# Create a new column and add a constant value
data["dense"] = 0

# Filter rows with above average pop density and update the column dense
data.loc[data["pop_density_km2"] > data["pop_density_km2"].mean(), "dense"] = 1

# %%
data.dense.value_counts()
# Out:
# dense
# 0    86
# 1    44
# Name: count, dtype: int64

# %%
# Conduct the aggregation
dissolved = data[["pop2019", "area_km2", "dense", "geometry"]].dissolve(
    by="dense", aggfunc="sum"
)
dissolved
# Out:
#                                                 geometry   pop2019    area_km2
# dense
# 0      MULTIPOLYGON (((614108.23 3339640.551, 614288....  368992.0  231.131494
# 1      MULTIPOLYGON (((612263.531 3338931.8, 612265.2...  242943.0   71.234570

# %%
dissolved = dissolved.reset_index()

# %%
dissolved.plot(column="dense")

plt.axis("off")
plt.show()

# %% [markdown]
# # Exercise
# ### Create a 500m buffer zone around the dense areas in Austin and plot a simple map of this zone.

# %%
ax1 = data.plot(color="grey")
dissolved.loc[dissolved["dense"] == 1].buffer(500).plot(ax=ax1, alpha=0.5, color="yellow")
# Out:
# <Axes: >

# %%
# Make a copy
option_1 = data.copy()
option_1["geometry"].head(2)
# Out:
# 0    MULTIPOLYGON (((615643.488 3338728.496, 615645...
# 1    MULTIPOLYGON (((618576.586 3359381.053, 618614...
# Name: geometry, dtype: geometry

# %%
# Update the geometry column with centroids
option_1["geometry"] = option_1.centroid
print(option_1.head(2))
# Out:
#    pop2019   tract  area_km2  pop_density_km2                        geometry  \
# 0   6070.0  002422  4.029772      1506.288778   POINT (616990.19 3339736.002)
# 1   2203.0  001751  1.532030      1437.961394  POINT (619378.303 3359650.002)
#
#    dense
# 0      0
# 1      0

# %%
# Make a copy and Create a column with centroids
option_2 = data.copy()
option_2["centroid"] = data.centroid
option_2.head(2)
# Out:
#    pop2019   tract  area_km2  pop_density_km2  \
# 0   6070.0  002422  4.029772      1506.288778
# 1   2203.0  001751  1.532030      1437.961394
#
#                                             geometry  dense  \
# 0  MULTIPOLYGON (((615643.488 3338728.496, 615645...      0
# 1  MULTIPOLYGON (((618576.586 3359381.053, 618614...      0
#
#                          centroid
# 0   POINT (616990.19 3339736.002)
# 1  POINT (619378.303 3359650.002)

# %%
# Use centroids as the GeoDataFrame geometries
option2 = option_2.set_geometry("centroid")
option2.head(2)
# Out:
#    pop2019   tract  area_km2  pop_density_km2  \
# 0   6070.0  002422  4.029772      1506.288778
# 1   2203.0  001751  1.532030      1437.961394
#
#                                             geometry  dense  \
# 0  MULTIPOLYGON (((615643.488 3338728.496, 615645...      0
# 1  MULTIPOLYGON (((618576.586 3359381.053, 618614...      0
#
#                          centroid
# 0   POINT (616990.19 3339736.002)
# 1  POINT (619378.303 3359650.002)

# %%
option2.geometry.name
# Out:
# 'centroid'

# %%
option2.plot();

# %%
import geopandas as gpd

# Read the file
fp = "data/_data/EU_countries/eu_countries_2022.gpkg"
data = gpd.read_file(fp)

# What is the type?
print(type(data.crs))

# Check the coordinate reference system information
data.crs
# Out:
# <class 'pyproj.crs.crs.CRS'>
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
data["geometry"].head()
# Out:
# 0    MULTIPOLYGON (((13.684 46.4375, 13.511 46.3484...
# 1    MULTIPOLYGON (((6.3156 50.497, 6.405 50.3233, ...
# 2    MULTIPOLYGON (((28.498 43.4341, 28.0602 43.316...
# 3    MULTIPOLYGON (((16.9498 48.5358, 16.8511 48.43...
# 4    MULTIPOLYGON (((32.9417 34.6418, 32.559 34.687...
# Name: geometry, dtype: geometry

# %%
# Let's make a backup copy of our data
data_wgs84 = data.copy()

# Reproject the data
data = data.to_crs(epsg=3035)

# Check the new geometry values
data["geometry"].head()
# Out:
# 0    MULTIPOLYGON (((4604288.477 2598607.47, 459144...
# 1    MULTIPOLYGON (((4059689.242 3049361.18, 406508...
# 2    MULTIPOLYGON (((5805367.757 2442801.252, 57739...
# 3    MULTIPOLYGON (((4833567.363 2848881.974, 48272...
# 4    MULTIPOLYGON (((6413299.362 1602181.345, 63782...
# Name: geometry, dtype: geometry

# %%
# Check the new EPSG code
data.crs.to_epsg()
# Out:
# 3035

# %%
import matplotlib.pyplot as plt

# Make subplots that are next to each other
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

# Plot the data in WGS84 CRS
data_wgs84.plot(ax=ax1, facecolor="gray")

# Plot the one with ETRS-LAEA projection
data.plot(ax=ax2, facecolor="blue", edgecolor="white", lw=0.5)

# Add titles
ax1.set_title("Austria")
ax2.set_title("ETRS Lambert Azimuthal Equal Area projection")

# Set aspect ratio as 1
ax1.set_aspect(aspect=1)
ax2.set_aspect(aspect=1)

# Remove empty white space around the plot
plt.tight_layout()

# %%
# Ouput filepath
outfp = "data/_data/EU_countries/Europe_borders_epsg3035.shp"

# Save to disk
data.to_file(outfp)

# %% [markdown]
# # Exercise
#
# ### Pick some CRS, e.g. ETRS89 / TM35FIN (EPSG:3067). And pick an EU country of your choice (e.g. Finland)
#
# ### First, select Finland from our dataset of EU countries; then, plot two maps of Finland where you compare the WGS84 (EPSG:4326) representation and ETRS89 / TM35FIN (EPSG:3067); you can achieve this by modifying the previous example for the whole EU.

# %%
data.head()
# Out:
#   CNTR_ID                CNTR_NAME NAME_ENGL NAME_FREN ISO3_CODE  \
# 0      IT                   Italia     Italy    Italie       ITA
# 1      BE  Belgien-Belgique-België   Belgium  Belgique       BEL
# 2      BG                 България  Bulgaria  Bulgarie       BGR
# 3      AT               Österreich   Austria  Autriche       AUT
# 4      CY            Κύπρος-Kıbrıs    Cyprus    Chypre       CYP
#
#            SVRG_UN      CAPT EU_STAT EFTA_STAT CC_STAT   NAME_GERM  \
# 0  UN Member State      Rome       T         F       F     Italien
# 1  UN Member State  Brussels       T         F       F     Belgien
# 2  UN Member State     Sofia       T         F       F   Bulgarien
# 3  UN Member State    Vienna       T         F       F  Österreich
# 4  UN Member State   Nicosia       T         F       F      Zypern
#
#                                             geometry
# 0  MULTIPOLYGON (((4604288.477 2598607.47, 459144...
# 1  MULTIPOLYGON (((4059689.242 3049361.18, 406508...
# 2  MULTIPOLYGON (((5805367.757 2442801.252, 57739...
# 3  MULTIPOLYGON (((4833567.363 2848881.974, 48272...
# 4  MULTIPOLYGON (((6413299.362 1602181.345, 63782...

# %%
finland_wgs84 = data_finland.loc[data_wgs84["NAME_ENGL"] == "Finland"].copy()
finland_etrs89 = finland_wgs84.to_crs(epsg=3067)

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 10))
# Plot the data in WGS84 CRS
finland_wgs84.plot(ax=ax1, facecolor="gray")

# Plot the one with ETRS-LAEA projection
finland_etrs89.plot(ax=ax2, facecolor="blue", edgecolor="white", lw=0.5)

# Add titles
ax1.set_title("Finland")
ax2.set_title("ETRS Lambert Azimuthal Equal Area projection")

# Set aspect ratio as 1
ax1.set_aspect(aspect=1)
ax2.set_aspect(aspect=1)

# Remove empty white space around the plot
plt.tight_layout()

# %%
from pyproj import CRS

crs_object = CRS.from_epsg(3035)

# %%
print("Name:", crs_object.name)
print("Coordinate system:", crs_object.coordinate_system)
print("Bounds:", crs_object.area_of_use.bounds)
print("Datum:", crs_object.datum)
# Out:
# Name: ETRS89-extended / LAEA Europe
# Coordinate system: cartesian
# Bounds: (-35.58, 24.6, 44.83, 84.73)
# Datum: European Terrestrial Reference System 1989 ensemble

# %%
crs_wkt = crs_object.to_wkt()

# %%
# Retrieve EPSG code from WKT text
epsg = CRS(crs_wkt).to_epsg()
print(epsg)
# Out:
# 3035

# %%
CRS(crs_wkt).to_epsg(min_confidence=25)
# Out:
# 3035

# %%
from shapely.geometry import Point

# Create GeoDataFrame with one point
gdf = gpd.GeoDataFrame({"geometry": Point(24.950899, 60.169158)}, index=[0])
print(gdf.crs)
# Out:
# None

# %%
from pyproj import CRS

gdf = gdf.set_crs(CRS.from_epsg(4326))
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import geopandas

fp = "data/_data/ne_110m_admin_0_countries.zip"
admin = gpd.read_file(fp)
admin.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Plot in original crs
admin.plot(figsize=(12, 6))
plt.title("WGS84");

# %%
admin.to_crs(epsg=3857).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec3d7b02aafa6611bd68351e40f95691 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec3d7b02aafa6611bd68351e40f95691&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec3d7b02aafa6611bd68351e40f95691 = L.map(
#                 &quot;map_ec3d7b02aafa6611bd68351e40f95691&quot;,
#                 {
#                     center: [-3.1774349999999956, 1.4210854715202004e-14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ec3d7b02aafa6611bd68351e40f95691);
#
#
#
#
#
#             var tile_layer_7202c77e5d261394fcc2d80c847017b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7202c77e5d261394fcc2d80c847017b9.addTo(map_ec3d7b02aafa6611bd68351e40f95691);
#
#
#             map_ec3d7b02aafa6611bd68351e40f95691.fitBounds(
#                 [[-90.0, -180.0], [83.64513000000001, 180.00000000000003]],
#                 {}
#             );
#
#
#         function geo_json_350eca539e900582b6372ff9173055fc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_350eca539e900582b6372ff9173055fc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_350eca539e900582b6372ff9173055fc_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_350eca539e900582b6372ff9173055fc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_350eca539e900582b6372ff9173055fc_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_350eca539e900582b6372ff9173055fc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_350eca539e900582b6372ff9173055fc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_350eca539e900582b6372ff9173055fc = L.geoJson(null, {
#                 onEachFeature: geo_json_350eca539e900582b6372ff9173055fc_onEachFeature,
#
#                 style: geo_json_350eca539e900582b6372ff9173055fc_styler,
#                 pointToLayer: geo_json_350eca539e900582b6372ff9173055fc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_350eca539e900582b6372ff9173055fc_add (data) {
#             geo_json_350eca539e900582b6372ff9173055fc
#                 .addData(data);
#         }
#             geo_json_350eca539e900582b6372ff9173055fc_add({&quot;bbox&quot;: [-180.0, -90.0, 180.00000000000003, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, -18.287990000000004, 180.0, -16.020882256741224], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[180.0, -16.067132663642447], [180.0, -16.5552165666392], [179.36414266196414, -16.801354076946883], [178.72505936299711, -17.012041674368035], [178.59683859511716, -16.639150000000004], [179.09660936299707, -16.433984277547403],

# %%
admin.to_crs(crs="ESRI:54012").plot(figsize=(12, 12))
plt.title("Eckert IV")
plt.axis("off");

# %%
proj_string = "+proj=ortho +lat_0=60.00 +lon_0=24.0000"
admin.to_crs(crs=proj_string).plot()
plt.axis("off")
plt.title("Orthographic");
# Out:
# C:\Users\Andriy\analytics\labs\.venv\Lib\site-packages\shapely\constructive.py:829: RuntimeWarning: invalid value encountered in normalize
#   return lib.normalize(geometry, **kwargs)
# C:\Users\Andriy\analytics\labs\.venv\Lib\site-packages\shapely\constructive.py:829: RuntimeWarning: invalid value encountered in normalize
#   return lib.normalize(geometry, **kwargs)

# %% [markdown]
# # Exercise
#
# ### Reproject the map around the place you were born in.

# %%
proj_string = "+proj=ortho +lat_0=50.078056 +lon_0=25.154167"
admin.to_crs(crs=proj_string).plot()
plt.axis("off")
plt.title("Броди");
# Out:
# C:\Users\Andriy\analytics\labs\.venv\Lib\site-packages\shapely\constructive.py:829: RuntimeWarning: invalid value encountered in normalize
#   return lib.normalize(geometry, **kwargs)

# %%
# Import necessary modules
import pandas as pd
import geopandas as gpd

# Filepath
fp = "data/_data/Helsinki/addresses.txt"

# Read the data
data = pd.read_csv(fp, sep=";")
data.head()
# Out:
#      id                                           addr
# 0  1000       Itämerenkatu 14, 00101 Helsinki, Finland
# 1  1001          Kampinkuja 1, 00100 Helsinki, Finland
# 2  1002           Kaivokatu 8, 00101 Helsinki, Finland
# 3  1003  Hermannin rantatie 1, 00580 Helsinki, Finland
# 4  1005     Tyynenmerenkatu 9, 00220 Helsinki, Finland

# %%
from geopandas.tools import geocode

geo = geocode(
    data["addr"], provider="nominatim", user_agent="Adriana0157", timeout=10
)
geo.head()
# Out:
#                     geometry  \
# 0   POINT (24.91556 60.1632)
# 1  POINT (24.93166 60.16905)
# 2  POINT (24.94146 60.17011)
# 3  POINT (24.97687 60.18748)
# 4  POINT (24.92151 60.15662)
#
#                                              address
# 0  Ruoholahti, 14, Itämerenkatu, Ruoholahti, Läns...
# 1  Kamppi, 1, Kampinkuja, Kamppi, Eteläinen suurp...
# 2  Social Burgerjoint, 8, Kaivokatu, Keskusta, Kl...
# 3  Kalasatama, 1, Hermannin rantatie, Suvilahti, ...
# 4  9, Tyynenmerenkatu, Jätkäsaari, Länsisatama, E...

# %%
join = geo.join(data)
join.head()
# Out:
#                     geometry  \
# 0   POINT (24.91556 60.1632)
# 1  POINT (24.93166 60.16905)
# 2  POINT (24.94146 60.17011)
# 3  POINT (24.97687 60.18748)
# 4  POINT (24.92151 60.15662)
#
#                                              address    id  \
# 0  Ruoholahti, 14, Itämerenkatu, Ruoholahti, Läns...  1000
# 1  Kamppi, 1, Kampinkuja, Kamppi, Eteläinen suurp...  1001
# 2  Social Burgerjoint, 8, Kaivokatu, Keskusta, Kl...  1002
# 3  Kalasatama, 1, Hermannin rantatie, Suvilahti, ...  1003
# 4  9, Tyynenmerenkatu, Jätkäsaari, Länsisatama, E...  1005
#
#                                             addr
# 0       Itämerenkatu 14, 00101 Helsinki, Finland
# 1          Kampinkuja 1, 00100 Helsinki, Finland
# 2           Kaivokatu 8, 00101 Helsinki, Finland
# 3  Hermannin rantatie 1, 00580 Helsinki, Finland
# 4     Tyynenmerenkatu 9, 00220 Helsinki, Finland

# %%
join.explore(color="red", marker_kwds={"radius": 5})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8db0ca01e2618250e3f5e4af45a8ada {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8db0ca01e2618250e3f5e4af45a8ada&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8db0ca01e2618250e3f5e4af45a8ada = L.map(
#                 &quot;map_e8db0ca01e2618250e3f5e4af45a8ada&quot;,
#                 {
#                     center: [60.217319399999994, 24.99473395],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e8db0ca01e2618250e3f5e4af45a8ada);
#
#
#
#
#
#             var tile_layer_fe3b4470a1662af8d57978ba6d2af031 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe3b4470a1662af8d57978ba6d2af031.addTo(map_e8db0ca01e2618250e3f5e4af45a8ada);
#
#
#             map_e8db0ca01e2618250e3f5e4af45a8ada.fitBounds(
#                 [[60.1566206, 24.8535694], [60.2780182, 25.1358985]],
#                 {}
#             );
#
#
#         function geo_json_e5de29bd344e6caa2355ce21e9ae8be5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e5de29bd344e6caa2355ce21e9ae8be5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e5de29bd344e6caa2355ce21e9ae8be5_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 5,
# };
#
#             let style = geo_json_e5de29bd344e6caa2355ce21e9ae8be5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e5de29bd344e6caa2355ce21e9ae8be5_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_e5de29bd344e6caa2355ce21e9ae8be5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e5de29bd344e6caa2355ce21e9ae8be5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e5de29bd344e6caa2355ce21e9ae8be5 = L.geoJson(null, {
#                 onEachFeature: geo_json_e5de29bd344e6caa2355ce21e9ae8be5_onEachFeature,
#
#                 style: geo_json_e5de29bd344e6caa2355ce21e9ae8be5_styler,
#                 pointToLayer: geo_json_e5de29bd344e6caa2355ce21e9ae8be5_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_e5de29bd344e6caa2355ce21e9ae8be5_add (data) {
#             geo_json_e5de29bd344e6caa2355ce21e9ae8be5
#                 .addData(data);
#         }
#             geo_json_e5de29bd344e6caa2355ce21e9ae8be5_add({&quot;bbox&quot;: [24.8535694, 60.1566206, 25.1358985, 60.2780182], &quot;features&quot;: [{&quot;bbox&quot;: [24.9155624, 60.1632015, 24.9155624, 60.1632015], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.9155624, 60.1632015], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;red&quot;, &quot;addr&quot;: &quot;I

# %% [markdown]
# # Exercise
# ### Do another round of geocoding with your own list of addresses from anywhere in the world. Are you happy with the result?
#
# ### In the above example we passed the address column to the geocoding function. The geopandas documentation of geopandas.tools.geocode confirms that we should also be able to pass a list of strings to the geocoding tool. So, you should be able to answer this question by defining a list of addresses and using this list as input strings.

# %%
address_list = [
    "Grand Canyon National Park, Arizona, USA",
    "Great Barrier Reef, Queensland, Australia",
    "Guanabara Bay, Brazil",
    "Mount Qomolangma",
    "Kangerlussuaq",
    "Parícutin",
    "Victoria Falls"
]

# %%
from geopandas.tools import geocode
geog = geocode(address_list, provider="nominatim", user_agent="geo_wonders", timeout=10)
geog
# Out:
#                       geometry  \
# 0   POINT (-112.2929 36.30785)
# 1  POINT (148.95213 -20.35814)
# 2   POINT (-43.12722 -22.8169)
# 3    POINT (86.92521 27.98806)
# 4   POINT (-50.69134 67.00868)
# 5  POINT (-102.25132 19.49317)
# 6   POINT (25.85201 -17.92399)
#
#                                              address
# 0  Grand Canyon National Park, Arizona, United St...
# 1  Hamilton Island Airport, Airport Drive, Whitsu...
# 2  Baía de Guanabara, Região Metropolitana do Rio...
# 3  珠穆朗玛峰 ཇོ་མོ་གླང་མ། सगरमाथा, खुम्बु पासाङल्हामु...
# 4           Kangerlussuaq, Qeqqata, Kalaallit Nunaat
# 5              Parícutin, Uruapan, Michoacán, México
# 6  Main Falls, Livingstone, Livingstone District,...

# %% [markdown]
# # Сiм прирoдниx чудec cвiту зa вeрciєю *CNN*

# %%
geog.explore(color="red", marker_kwds={"radius": 5})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d564fbe85a9af3b413a987a198dedfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d564fbe85a9af3b413a987a198dedfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d564fbe85a9af3b413a987a198dedfc = L.map(
#                 &quot;map_1d564fbe85a9af3b413a987a198dedfc&quot;,
#                 {
#                     center: [22.0958872, 18.3296171],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1d564fbe85a9af3b413a987a198dedfc);
#
#
#
#
#
#             var tile_layer_659d9a877b9812831389bcc1e253c01f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_659d9a877b9812831389bcc1e253c01f.addTo(map_1d564fbe85a9af3b413a987a198dedfc);
#
#
#             map_1d564fbe85a9af3b413a987a198dedfc.fitBounds(
#                 [[-22.8169023, -112.292896], [67.0086767, 148.9521302]],
#                 {}
#             );
#
#
#         function geo_json_1d1afc0712f839a0d1d986daa1f788dc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1d1afc0712f839a0d1d986daa1f788dc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1d1afc0712f839a0d1d986daa1f788dc_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 5,
# };
#
#             let style = geo_json_1d1afc0712f839a0d1d986daa1f788dc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1d1afc0712f839a0d1d986daa1f788dc_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1d1afc0712f839a0d1d986daa1f788dc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1d1afc0712f839a0d1d986daa1f788dc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1d1afc0712f839a0d1d986daa1f788dc = L.geoJson(null, {
#                 onEachFeature: geo_json_1d1afc0712f839a0d1d986daa1f788dc_onEachFeature,
#
#                 style: geo_json_1d1afc0712f839a0d1d986daa1f788dc_styler,
#                 pointToLayer: geo_json_1d1afc0712f839a0d1d986daa1f788dc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_1d1afc0712f839a0d1d986daa1f788dc_add (data) {
#             geo_json_1d1afc0712f839a0d1d986daa1f788dc
#                 .addData(data);
#         }
#             geo_json_1d1afc0712f839a0d1d986daa1f788dc_add({&quot;bbox&quot;: [-112.292896, -22.8169023, 148.9521302, 67.0086767], &quot;features&quot;: [{&quot;bbox&quot;: [-112.292896, 36.3078548, -112.292896, 36.3078548], &quot;geometry&quot;: {&quot;coordinates&quot;: [-112.292896, 36.3078548], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;red&quot;, &quot;address&quot;: &quo

# %%
points = geo[["geometry"]].copy()
points.head()
# Out:
#                     geometry
# 0   POINT (24.91556 60.1632)
# 1  POINT (24.93166 60.16905)
# 2  POINT (24.94146 60.17011)
# 3  POINT (24.97687 60.18748)
# 4  POINT (24.92151 60.15662)

# %%
from geopandas.tools import reverse_geocode

reverse_geocoded = reverse_geocode(
    points.geometry, provider="nominatim", user_agent="quarto_lnu", timeout=10
)
reverse_geocoded.head()
# Out:
#                     geometry  \
# 0   POINT (24.91556 60.1632)
# 1  POINT (24.93166 60.16905)
# 2  POINT (24.94146 60.17011)
# 3  POINT (24.97687 60.18748)
# 4  POINT (24.92151 60.15662)
#
#                                              address
# 0  Ruoholahti, 14, Itämerenkatu, Ruoholahti, Läns...
# 1  Kamppi, 1, Kampinkuja, Kamppi, Eteläinen suurp...
# 2  Social Burgerjoint, 8, Kaivokatu, Keskusta, Kl...
# 3  Kalasatama, 1, Hermannin rantatie, Suvilahti, ...
# 4  9, Tyynenmerenkatu, Jätkäsaari, Länsisatama, E...
